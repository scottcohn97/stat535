# %% [markdown]
# # Simulations [TEST]

# %% [markdown]
# Scott Cohn
#
# Apr 2020
#
# Stat 535

# %%
import os
import sys

import matplotlib.pyplot as plt
import pandas as pd

sys.path.insert(0, 'stat535/lib/')

from Game import *
from sim_funcs import *

# %% [markdown]
# ## Initial Conditions

# %%
numAgents = 100
giniArr = [0.1, 0.3, 0.5, 0.7, 0.9]
numSims = 100

# %% [markdown]
# ### Game Instance - Gini = 0.1

# %% [markdown]
# The initial conditions are as follows:
#
# - Agents = 100
# - Gini = 0.1
# - mu = 2
# - numSims = 25

# %%
g = Game(numAgent = numAgents, Gini = giniArr[0])

# %%
nx.draw(g.network)

# %%
strat_distribution(g)
# Out:
# Cooperate: 31 Defect: 39 Random: 30
# <BarContainer object of 3 artists>

# %% [markdown]
# Confirm starting gini value:

# %%
g.gini()
# 0.12354
# Out:
# 0.12354761487709465

# %% [markdown]
# Plot inital wealth distribution at time = 0.

# %%
# wealth distr init

y = g.wealth_distr()

for _ in y:
    plt.scatter(range(len(y)), y, c = 'g')

# %% [markdown]
# The distribution looks more or less random. We can look by at the distribution by `strategy`.

# %%
strat_plot(g)

# %% [markdown]
# Then, we run the simulation for `numSims` times.

# %%
g_fin = sim(g, numSims)

# %%
# check the post-run Gini

g_fin.gini()
# 0.554 
# increased by 0.43
# Out:
# 0.554525407599651

# %% [markdown]
# Plot wealth distribution after simulations:

# %%
# wealth distr fin

y2 = g_fin.wealth_distr()

for _ in y2:
    plt.scatter(range(len(y2)), y2, c = 'c')

# %% [markdown]
# This looks completely bifurcated. Then, by `strategy`.

# %%
strat_plot(g_fin)

# %% [markdown]
# Division almost entirely by strategy chosen.

# %% [markdown]
# Draw network:

# %%
nx.draw(g_fin.network)

# %% [markdown]
# Change in wealth over time:

# %%
# need df of wealth over time

init_df = game_df(g)
fin_df = game_df(g_fin)

# %%
init_df.head()
# Out:
#    id strategies  assets
# 0   0     defect       6
# 1   1     random       8
# 2   2     random       8
# 3   3     random      11
# 4   4     random       8

# %%
fin_df.head()
# Out:
#    id strategies  assets
# 0   0     random    1616
# 1   1       coop     186
# 2   2       coop     217
# 3   3     defect    5513
# 4   4     random     318

# %%
df = init_df.merge(fin_df, on='id', how='left', suffixes = ('_pre', '_post'))

# %%
df.head()

# Does the strategy change midgame?
# Out:
#    id strategies_pre  assets_pre strategies_post  assets_post
# 0   0         defect           6          random         1616
# 1   1         random           8            coop          186
# 2   2         random           8            coop          217
# 3   3         random          11          defect         5513
# 4   4         random           8          random          318

# %%
x1 = 100 * (1, )
x2 = 100 * (2, )
plt.plot(x1, df["assets_pre"], marker="o", color = 'g', linestyle="", label=id)
plt.plot(x2, df["assets_post"], marker="o", color = 'b', linestyle="", label=id)

# %% [markdown]
# Total divergence in wealth.
