# %% [markdown]
# # Simulations [TEST]

# %% [markdown]
# Scott Cohn
#
# Apr 2020
#
# Stat 535

# %%
import os
import sys

sys.path.insert(0, 'stat535/lib/')

from Game import *
from misc_funcs import *

# %%
numAgents = 100
giniArr = [0.1, 0.3, 0.5, 0.7, 0.9]
mu = 10
numSims = 100

# %% [markdown]
# ## Initial Conditions

# %% [markdown]
# ### Game Instance - Gini = 0.9

# %% [markdown]
# The initial conditions are as follows:
#
# - Agents = 100
# - Gini = 0.9
# - mu = 10
# - numSims = 25
# - prob = [1,0,0,0](all cooperate)

# %%
g = Game(numAgent = numAgents, Gini = giniArr[4], prob = [0,1,0,0])

# %%
nx.draw(g.network)
# Out:
# C:\Users\Vignesh\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
strat_distribution(g, numAgents)
# Out:
# Cooperate: 0 Defect: 100 Random: 0
# <BarContainer object of 3 artists>

# %%
g.gini(0)
# 0.8232
# Out:
# 0.8504105528773752

# %%
# wealth distr init

y = g.wealth_distr(0)

for _ in y:
    plt.scatter(range(len(y)), y, c = 'g')

# %%
strat_plot(g, numAgents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b728e9102114> in <module>
# ----> 1 strat_plot(g, numAgents)
#
# ~\Documents\GitHub\stat535\lib\misc_funcs.py in strat_plot(g, numAgents)
#      57     groups = df.groupby("id")
#      58     for strategies, assets in groups:
# ---> 59         plt.plot(df["strategies"], df["assets"], marker="o", color = 'g', linestyle="", label=id)
#      60
#      61 def sim(g, N):
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
g_fin = sim(g, numSims)

# %%
# check the post-run Gini

g_fin.gini(numSims)
# 0.536
# decreased by 0.2692
# Out:
# 0.8373915997537941

# %%
# wealth distr fin

y2 = g_fin.wealth_distr(numSims)

for _ in y2:
    plt.scatter(range(len(y2)), y2, c = 'c')

# %%
strat_plot(g_fin, numAgents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3e46eee292bc> in <module>
# ----> 1 strat_plot(g_fin, numAgents)
#
# ~\Documents\GitHub\stat535\lib\misc_funcs.py in strat_plot(g, numAgents)
#      57     groups = df.groupby("id")
#      58     for strategies, assets in groups:
# ---> 59         plt.plot(df["strategies"], df["assets"], marker="o", color = 'g', linestyle="", label=id)
#      60
#      61 def sim(g, N):
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
nx.draw(g_fin.network)

# %%
# need df of wealth over time

init_df = game_df(g, numAgents)
fin_df = game_df(g_fin, numAgents)

# %%
df = init_df.merge(fin_df, on='id', how='left', suffixes = ('_pre', '_post'))

# %%
x1 = 100 * (1, )
x2 = 100 * (2, )
plt.plot(x1, df["assets_pre"], marker="o", color = 'g', linestyle="", label=id)
plt.plot(x2, df["assets_post"], marker="o", color = 'b', linestyle="", label=id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f839c64df487> in <module>
#       1 x1 = 100 * (1, )
#       2 x2 = 100 * (2, )
# ----> 3 plt.plot(x1, df["assets_pre"], marker="o", color = 'g', linestyle="", label=id)
#       4 plt.plot(x2, df["assets_post"], marker="o", color = 'b', linestyle="", label=id)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...
