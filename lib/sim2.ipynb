# %% [markdown]
# # Simulations [TEST]

# %% [markdown]
# Scott Cohn
#
# Apr 2020
#
# Stat 535

# %%
import os
import sys

import matplotlib.pyplot as plt
import pandas as pd

sys.path.insert(0, 'stat535/lib/')

from Game import *
import misc_funcs

# %%
numAgents = 100
giniArr = [0.1, 0.3, 0.5, 0.7, 0.9]
mu = 2
numSims = 100

# %% [markdown]
# ## Initial Conditions

# %% [markdown]
# ### Game Instance - Gini = 0.9

# %% [markdown]
# The initial conditions are as follows:
#
# - Agents = 100
# - Gini = 0.9
# - mu = 2
# - numSims = 25

# %%
g = Game(numAgent = numAgents, Gini = giniArr[4], para = mu)

# %%
nx.draw(g.network)

# %%
strat_distribution(g)
# Out:
# Cooperate: 36 Defect: 30 Random: 34
# <BarContainer object of 3 artists>

# %%
g.gini()
# 0.8232
# Out:
# 0.8232742361373067

# %%
# wealth distr init

y = g.wealth_distr()

for _ in y:
    plt.scatter(range(len(y)), y, c = 'g')

# %%
strat_plot(g)

# %%
g_fin = sim(g, numSims)

# %%
# check the post-run Gini

g_fin.gini()
# 0.536
# decreased by 0.2692
# Out:
# 0.5366949819815704

# %%
# wealth distr fin

y2 = g_fin.wealth_distr()

for _ in y2:
    plt.scatter(range(len(y2)), y2, c = 'c')

# %%
strat_plot(g_fin)

# %%
nx.draw(g_fin.network)

# %%
# need df of wealth over time

init_df = game_df(g)
fin_df = game_df(g_fin)

# %%
df = init_df.merge(fin_df, on='id', how='left', suffixes = ('_pre', '_post'))

# %%
x1 = 100 * (1, )
x2 = 100 * (2, )
plt.plot(x1, df["assets_pre"], marker="o", color = 'g', linestyle="", label=id)
plt.plot(x2, df["assets_post"], marker="o", color = 'b', linestyle="", label=id)
